# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
toronto_data = pd.read_csv("listings.csv")

# %%
toronto_data
# Out:
#                        id                                               name  \
# 0                  701230                     Authentic Bright Artist's Loft
# 1                   40456                Downtown- King Size Bed and Parking
# 2                    1419                    Beautiful home in amazing area!
# 3                    8077                 Downtown Harbourfront Private Room
# 4                   26654  World Class downtown @CN Tower Theatre MTCC ga...
# ...                   ...                                                ...
# 17992  842700374677803131     Fresh 4BR Haven in Forest Hill w BBQ Gym Sauna
# 17993  842723832769919194                                Condo near Downtown
# 17994  842749526057328073                    Whole Modern TownHome@Downsview
# 17995  842797078204247527  NEW LUX Condo with CN Tower Views (2 BED | 2 B...
# 17996  842820235890657160           Stunning 3BR Bluffs Home Near the Water!
#
# ...

# %%
df = pd.DataFrame(toronto_data)
df.head()
# Out:
#        id                                               name  host_id  \
# 0  701230                     Authentic Bright Artist's Loft  3587917
# 1   40456                Downtown- King Size Bed and Parking   174063
# 2    1419                    Beautiful home in amazing area!     1565
# 3    8077                 Downtown Harbourfront Private Room    22795
# 4   26654  World Class downtown @CN Tower Theatre MTCC ga...   113345
#
#         host_name  neighbourhood_group                      neighbourhood  \
# 0           Darby                  NaN                    High Park North
# 1           Denis                  NaN                     South Parkdale
# 2       Alexandra                  NaN                    Little Portugal
# 3  Kathie & Larry                  NaN  Waterfront Communities-The Island
# 4           Adela                  NaN  Waterfront Communities-The Island
#
#    latitude  longitude        room_type  price  minimum_nights  \
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17997 entries, 0 to 17996
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              17997 non-null  int64
#  1   name                            17995 non-null  object
#  2   host_id                         17997 non-null  int64
#  3   host_name                       17995 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   17997 non-null  object
#  6   latitude                        17997 non-null  float64
#  7   longitude                       17997 non-null  float64
#  8   room_type                       17997 non-null  object
#  9   price                           17997 non-null  int64
#  10  minimum_nights                  17997 non-null  int64
#  11  number_of_reviews               17997 non-null  int64
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17992    False
# 17993    False
# 17994    False
# 17995    False
# 17996    False
# Length: 17997, dtype: bool

# %%
clean_df = df.drop_duplicates()

# %%
clean_df
# Out:
#                        id                                               name  \
# 0                  701230                     Authentic Bright Artist's Loft
# 1                   40456                Downtown- King Size Bed and Parking
# 2                    1419                    Beautiful home in amazing area!
# 3                    8077                 Downtown Harbourfront Private Room
# 4                   26654  World Class downtown @CN Tower Theatre MTCC ga...
# ...                   ...                                                ...
# 17992  842700374677803131     Fresh 4BR Haven in Forest Hill w BBQ Gym Sauna
# 17993  842723832769919194                                Condo near Downtown
# 17994  842749526057328073                    Whole Modern TownHome@Downsview
# 17995  842797078204247527  NEW LUX Condo with CN Tower Views (2 BED | 2 B...
# 17996  842820235890657160           Stunning 3BR Bluffs Home Near the Water!
#
# ...

# %%
clean_df = clean_df.drop(columns=['neighbourhood_group'])

# %%
clean_df
# Out:
#                        id                                               name  \
# 0                  701230                     Authentic Bright Artist's Loft
# 1                   40456                Downtown- King Size Bed and Parking
# 2                    1419                    Beautiful home in amazing area!
# 3                    8077                 Downtown Harbourfront Private Room
# 4                   26654  World Class downtown @CN Tower Theatre MTCC ga...
# ...                   ...                                                ...
# 17992  842700374677803131     Fresh 4BR Haven in Forest Hill w BBQ Gym Sauna
# 17993  842723832769919194                                Condo near Downtown
# 17994  842749526057328073                    Whole Modern TownHome@Downsview
# 17995  842797078204247527  NEW LUX Condo with CN Tower Views (2 BED | 2 B...
# 17996  842820235890657160           Stunning 3BR Bluffs Home Near the Water!
#
# ...
